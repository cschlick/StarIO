# %% [markdown]
# In this notebook we will read a Relion star file, subset it, and write it back to disk.

# %%
import pandas as pd
from StarIO import read_star, write_star

# %% [markdown]
# # Read a star file

# %%
df_dict = read_star("examples/run_it013_data.star")

# %%
print(df_dict.keys())
# Out:
# dict_keys(['data'])

# %% [markdown]
# Here we have only one dataframe, with the generic name "data". To access the data frame from the dictionary:

# %%
df = df_dict["data"]

# %%
df
# Out:
#                                        rlnMicrographName  rlnCoordinateX  \
# 0      MotionCorr/job002/Micrographs/20191025_1252_A0...      834.545410
# 1      MotionCorr/job002/Micrographs/20191025_1252_A0...     1243.636230
# 2      MotionCorr/job002/Micrographs/20191025_1252_A0...     3402.624023
# 3      MotionCorr/job002/Micrographs/20191025_1252_A0...     4074.545166
# 4      MotionCorr/job002/Micrographs/20191025_1252_A0...     1963.636353
# ...                                                  ...             ...
# 22749  MotionCorr/job002/Micrographs/20191025_1252_A0...     3747.272461
# 22750  MotionCorr/job002/Micrographs/20191025_1252_A0...      439.259766
# 22751  MotionCorr/job002/Micrographs/20191025_1252_A0...     2912.727051
# 22752  MotionCorr/job002/Micrographs/20191025_1252_A0...     1947.272583
# 22753  MotionCorr/job002/Micrographs/20191025_1252_A0...     2879.999756
#
#        rlnCoordinateY                                       rlnImageName  \
# 0          850.909058  000012@Extract/job012/Micrographs/20191025_125...
# 1         2961.817871  000015@Extract/job012/Micrographs/20191025_125...
# 2         1960.278687  000017@Extract/job012/Micrographs/20191025_125...
# 3         1930.908936  000001@Extract/job012/Micrographs/20191025_125...
# 4         1881.818115  000002@Extract/job012/Micrographs/20191025_125...
# ...               ...                                                ...
# 22749     1079.999878  000016@Extract/job012/Micrographs/20191025_125...
# 22750     2950.251953  000017@Extract/job012/Micrographs/20191025_125...
# 22751     1030.909058  000001@Extract/job012/Micrographs/20191025_125...
# 22752     3469.090576  000004@Extract/job012/Micrographs/20191025_125...
# 22753     3583.636230  000008@Extract/job012/Micrographs/20191025_125...
#
#         rlnDefocusU   rlnDefocusV  rlnDefocusAngle  rlnPhaseShift  rlnVoltage  \
# 0      15376.422852  14312.515625        23.760529            0.0       200.0
# 1      15376.422852  14312.515625        23.760529            0.0       200.0
# 2      15376.422852  14312.515625        23.760529            0.0       200.0
# 3      15376.422852  14312.515625        23.760529            0.0       200.0
# 4      15376.422852  14312.515625        23.760529            0.0       200.0
# ...             ...           ...              ...            ...         ...
# 22749   5558.317383   4541.786621        28.256891            0.0       200.0
# 22750   5558.317383   4541.786621        28.256891            0.0       200.0
# 22751   5558.317383   4541.786621        28.256891            0.0       200.0
# 22752   5558.317383   4541.786621        28.256891            0.0       200.0
# 22753   5558.317383   4541.786621        28.256891            0.0       200.0
#
#        rlnSphericalAberration  ...  rlnCtfMaxResolution  rlnCtfFigureOfMerit  \
# 0                         2.7  ...             4.569044             0.071087
# 1                         2.7  ...             4.569044             0.071087
# 2                         2.7  ...             4.569044             0.071087
# 3                         2.7  ...             4.569044             0.071087
# 4                         2.7  ...             4.569044             0.071087
# ...                       ...  ...                  ...                  ...
# 22749                     2.7  ...             4.750596             0.058816
# 22750                     2.7  ...             4.750596             0.058816
# 22751                     2.7  ...             4.750596             0.058816
# 22752                     2.7  ...             4.750596             0.058816
# 22753                     2.7  ...             4.750596             0.058816
#
#        rlnGroupNumber  rlnClassNumber  rlnNormCorrection  \
# 0                   1               1           0.857364
# 1                   1               1           0.862628
# 2                   1               1           0.871292
# 3                   1               1           0.871992
# 4                   1               1           0.876302
# ...               ...             ...                ...
# 22749              79               1           0.831493
# 22750              79               1           0.816456
# 22751              79               1           0.833504
# 22752              79               1           0.834830
# 22753              79               1           0.838140
#
#        rlnLogLikeliContribution  rlnMaxValueProbDistribution  \
# 0                  58808.724788                     0.205808
# 1                  59673.819842                     0.235101
# 2                  59321.599249                     0.216328
# 3                  59331.710372                     0.679952
# 4                  59315.162707                     0.415812
# ...                         ...                          ...
# 22749              61889.461934                     0.076569
# 22750              61117.169326                     0.145702
# 22751              61835.396813                     0.087845
# 22752              62320.116387                     0.175700
# 22753              62035.009121                     0.046051
#
#        rlnNrOfSignificantSamples  rlnGroupName  rlnRandomSubset
# 0                             14      group_78                2
# 1                              8      group_78                1
# 2                             22      group_78                2
# 3                              2      group_78                2
# 4                              2      group_78                1
# ...                          ...           ...              ...
# 22749                         48      group_02                2
# 22750                         72      group_02                1
# 22751                         25      group_02                2
# 22752                          7      group_02                1
# 22753                        179      group_02                1
#
# [22754 rows x 28 columns]

# %% [markdown]
# # Take a simple subset (the top 5 particles)

# %%
subset = df.iloc[:5]

# %%
subset
# Out:
#                                    rlnMicrographName  rlnCoordinateX  \
# 0  MotionCorr/job002/Micrographs/20191025_1252_A0...      834.545410
# 1  MotionCorr/job002/Micrographs/20191025_1252_A0...     1243.636230
# 2  MotionCorr/job002/Micrographs/20191025_1252_A0...     3402.624023
# 3  MotionCorr/job002/Micrographs/20191025_1252_A0...     4074.545166
# 4  MotionCorr/job002/Micrographs/20191025_1252_A0...     1963.636353
#
#    rlnCoordinateY                                       rlnImageName  \
# 0      850.909058  000012@Extract/job012/Micrographs/20191025_125...
# 1     2961.817871  000015@Extract/job012/Micrographs/20191025_125...
# 2     1960.278687  000017@Extract/job012/Micrographs/20191025_125...
# 3     1930.908936  000001@Extract/job012/Micrographs/20191025_125...
# 4     1881.818115  000002@Extract/job012/Micrographs/20191025_125...
#
#     rlnDefocusU   rlnDefocusV  rlnDefocusAngle  rlnPhaseShift  rlnVoltage  \
# 0  15376.422852  14312.515625        23.760529            0.0       200.0
# 1  15376.422852  14312.515625        23.760529            0.0       200.0
# 2  15376.422852  14312.515625        23.760529            0.0       200.0
# 3  15376.422852  14312.515625        23.760529            0.0       200.0
# 4  15376.422852  14312.515625        23.760529            0.0       200.0
#
#    rlnSphericalAberration  ...  rlnCtfMaxResolution  rlnCtfFigureOfMerit  \
# 0                     2.7  ...             4.569044             0.071087
# 1                     2.7  ...             4.569044             0.071087
# 2                     2.7  ...             4.569044             0.071087
# 3                     2.7  ...             4.569044             0.071087
# 4                     2.7  ...             4.569044             0.071087
#
#    rlnGroupNumber  rlnClassNumber  rlnNormCorrection  \
# 0               1               1           0.857364
# 1               1               1           0.862628
# 2               1               1           0.871292
# 3               1               1           0.871992
# 4               1               1           0.876302
#
#    rlnLogLikeliContribution  rlnMaxValueProbDistribution  \
# 0              58808.724788                     0.205808
# 1              59673.819842                     0.235101
# 2              59321.599249                     0.216328
# 3              59331.710372                     0.679952
# 4              59315.162707                     0.415812
#
#    rlnNrOfSignificantSamples  rlnGroupName  rlnRandomSubset
# 0                         14      group_78                2
# 1                          8      group_78                1
# 2                         22      group_78                2
# 3                          2      group_78                2
# 4                          2      group_78                1
#
# [5 rows x 28 columns]

# %% [markdown]
# # Write the datframe to a file

# %%
write_star("examples/subset.star",subset)

# %% [markdown]
# Some other star files:

# %%
df_dict = read_star("examples/run_it013_half2_model.star")

# %%
df_dict.keys()
# Out:
# dict_keys(['model_general', 'model_classes', 'model_class_1', 'model_groups', 'model_group_1', 'model_group_2', 'model_group_3', 'model_group_4', 'model_group_5', 'model_group_6', 'model_group_7', 'model_group_8', 'model_group_9', 'model_group_10', 'model_group_11', 'model_group_12', 'model_group_13', 'model_group_14', 'model_group_15', 'model_group_16', 'model_group_17', 'model_group_18', 'model_group_19', 'model_group_20', 'model_group_21', 'model_group_22', 'model_group_23', 'model_group_24', 'model_group_25', 'model_group_26', 'model_group_27', 'model_group_28', 'model_group_29', 'model_group_30', 'model_group_31', 'model_group_32', 'model_group_33', 'model_group_34', 'model_group_35', 'model_group_36', 'model_group_37', 'model_group_38', 'model_group_39', 'model_group_40', 'model_group_41', 'model_group_42', 'model_group_43', 'model_group_44', 'model_group_45', 'model_group_46', 'model_group_47', 'model_group_48', 'model_group_49', 'model_group_50', 'model_group_51', 'model_group_52', 'model_group_53', 'model_group_54', 'model_group_55', 'model_group_56', 'model_group_57', 'model_group_58', 'model_group_59', 'model_group_60', 'model_group_61', 'model_group_62', 'model_group_63', 'model_group_64', 'model_group_65', 'model_group_66', 'model_group_67', 'model_group_68', 'model_group_69', 'model_group_70', 'model_group_71', 'model_group_72', 'model_group_73', 'model_group_74', 'model_group_75', 'model_group_76', 'model_group_77', 'model_group_78', 'model_group_79', 'model_group_80', 'model_group_81', 'model_group_82', 'model_group_83', 'model_group_84', 'model_group_85', 'model_group_86', 'model_group_87', 'model_group_88', 'model_group_89', 'model_group_90', 'model_group_91', 'model_group_92', 'model_group_93', 'model_group_94', 'model_group_95', 'model_group_96', 'model_group_97', 'model_pdf_orient_class_1'])

# %%
df_dict["model_group_69"]
# Out:
#      rlnSpectralIndex  rlnResolution  rlnSigma2Noise
# 0                   0       0.000000        0.000023
# 1                   1       0.001097        0.000013
# 2                   2       0.002195        0.000005
# 3                   3       0.003292        0.000004
# 4                   4       0.004389        0.000003
# ..                ...            ...             ...
# 252               252       0.276510        0.000002
# 253               253       0.277607        0.000002
# 254               254       0.278704        0.000002
# 255               255       0.279802        0.000002
# 256               256       0.280899        0.000002
#
# [257 rows x 3 columns]

# %%
df_dict = read_star("examples/run_it013_optimiser.star")

# %%
df_dict.keys()
# Out:
# dict_keys(['optimiser_general'])

# %%
df_dict["optimiser_general"]
# Out:
#      rlnOutputRootName                            rlnModelStarFile  \
# 0  Refine3D/job020/run  Refine3D/job020/run_it013_half1_model.star
#
#                             rlnModelStarFile2  \
# 0  Refine3D/job020/run_it013_half2_model.star
#
#            rlnExperimentalDataStarFile  \
# 0  Refine3D/job020/run_it013_data.star
#
#                  rlnOrientSamplingStarFile  rlnCurrentIteration  \
# 0  Refine3D/job020/run_it013_sampling.star                   13
#
#    rlnNumberOfIterations  rlnDoSplitRandomHalves  \
# 0                    999                       1
#
#    rlnJoinHalvesUntilThisResolution  rlnAdaptiveOversampleOrder  ...  \
# 0                              40.0                           1  ...
#
#    rlnDoCorrectCtf  rlnDoRealignMovies  rlnDoIgnoreCtfUntilFirstPeak  \
# 0                0                   0                             0
#
#    rlnCtfDataArePhaseFlipped  rlnCtfDataAreCtfPremultiplied  \
# 0                          0                              0
#
#    rlnDoOnlyFlipCtfPhases  rlnRefsAreCtfCorrected rlnFixSigmaNoiseEstimates  \
# 0                       0                       0                         0
#
#   rlnFixSigmaOffsetEstimates rlnMaxNumberOfPooledParticles
# 0                          0                             9
#
# [1 rows x 83 columns]
